# %% [markdown]
# #Instal library

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
# !pip install pandas
# !pip install numpy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %% [markdown]
# #scrape all available reviews

# %%
from numpy._core.defchararray import count
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.netflix.mediaclient',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=10000,
    filter_score_with=None
)

# %% [markdown]
# #show dta yang sudah di crawling

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review']) #nama file bebas
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.tail()
# Out:
#                                   reviewId                          userName  \
# 9995  c1fab9bf-0b5d-4038-8164-7cbd77a7d637                     Agus Helmi MK
# 9996  fcb5a9df-d04e-46bd-a3c4-b1c2bb15570c                  Revandra Zaedani
# 9997  316d5de4-97b5-435d-9597-723701c3c84e                             yanto
# 9998  7e32cf36-9300-4eec-8553-09dd662fb9b3  Chandra Ade Putra Simanjuntak SH
# 9999  1f22e588-3424-412b-a67a-b634d8b68c25      Arlizah Rizki Raya Ramadhani
#
#                                               userImage  \
# 9995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                       content  score  thumbsUpCount  \
# 9995                                   Mantap      5              0
# 9996   Jadiin genap 50 k ajadah nanggung amat      1              0
# 9997                                   Kamu 😀      1              0
# 9998                                       Ok      5              0
# 9999  Gabisa bikin akun ,gtw knp,gajelas gitu      3              0
#
#         reviewCreatedVersion                  at replyContent repliedAt  \
# 9995  8.140.1 build 14 51170 2024-12-04 13:50:01         None      None
# 9996                    None 2024-12-04 13:41:51         None      None
# 9997                    None 2024-12-04 11:18:27         None      None
# 9998  8.140.1 build 14 51170 2024-12-04 11:16:30         None      None
# 9999  8.140.1 build 14 51170 2024-12-04 07:28:15         None      None
#
#                   appVersion
# 9995  8.140.1 build 14 51170
# 9996                    None
# 9997                    None
# 9998  8.140.1 build 14 51170
# 9999  8.140.1 build 14 51170

# %%
len(df_busu.index)
# Out:
# 10000

# %% [markdown]
# #ambil data yang dibutuhkan

# %%
df_busu[['userName', 'score', 'at', 'content']].tail()
# Out:
#                               userName  score                  at  \
# 9995                     Agus Helmi MK      5 2024-12-04 13:50:01
# 9996                  Revandra Zaedani      1 2024-12-04 13:41:51
# 9997                             yanto      1 2024-12-04 11:18:27
# 9998  Chandra Ade Putra Simanjuntak SH      5 2024-12-04 11:16:30
# 9999      Arlizah Rizki Raya Ramadhani      3 2024-12-04 07:28:15
#
#                                       content
# 9995                                   Mantap
# 9996   Jadiin genap 50 k ajadah nanggung amat
# 9997                                   Kamu 😀
# 9998                                       Ok
# 9999  Gabisa bikin akun ,gtw knp,gajelas gitu

# %%
my_df =df_busu[['userName', 'score', 'at', 'content']]

# %% [markdown]
# #simpan dataset ke dalam file

# %%
my_df.to_csv("Datasetnetflix.csv", index = False)
